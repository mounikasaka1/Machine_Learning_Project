# %%
# Cell 1: Imports & Load Dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

df = pd.read_csv('FIC.Full CSV.csv')
df.head()
# Out:
#    Age Age.Group  Gender Locality   Marital status                         \
# 0   45     41-50  Female      RURAL                               MARRIED
# 1   51     51-60  Female      URBAN                               MARRIED
# 2   55     51-60  Female      RURAL                               MARRIED
# 3   55     51-60  Female      RURAL                               MARRIED
# 4   56     51-60  Female      RURAL                               MARRIED
#
#   Life.Style                                                                                \
# 0                                                 NO
# 1                                                 NO
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num SK  \
# 0    NO     FREE        YES       YES  ...     3.0     2   0     7   2  1
# 1    NO     FREE        YES       YES  ...     1.2     2   0     7   2  1
# 2   YES     FREE        YES       YES  ...     3.4     2   0     3   2  1
# 3   YES     FREE        YES       YES  ...     2.0     2   1     7   3  1
# 4    NO     FREE        YES       YES  ...     4.0     3   2     7   3  1
#
#    SK.React  Reaction  Mortality  Follow.Up
# 0        NO         0          0         60
# 1        NO         0          0         15
# 2        NO         0          0          6
# 3        NO         0          0         52
# 4        NO         0          0         34
#
# [5 rows x 60 columns]

# %%
# Cell 2: Exploratory Data Analysis
#  - structure, dtypes, missing, duplicates, descriptive stats
print("Shape:", df.shape)
print(df.info())
print("\nMissing values:\n", df.isnull().sum())
print("\nDuplicates:", df.duplicated().sum())
df.describe(include='all').T
# Out:
# Shape: (368, 60)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 60 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Age                                                                                       368 non-null    int64
#  1   Age.Group                                                                                 368 non-null    object
#  2   Gender                                                                                    368 non-null    object
#  3   Locality                                                                                  368 non-null    object
#  4   Marital status                                                                            368 non-null    object
#  5   Life.Style                                                                                368 non-null    object
#  6   Sleep                                                                                     368 non-null    object
#  7   Category                                                                                  368 non-null    object
#  8   Depression                                                                                368 non-null    object
#  9   Hyperlipi                                                                                 368 non-null    object
#  10  Smoking                                                                                   368 non-null    object
#  11  Family.History                                                                            368 non-null    object
#  12  F.History                                                                                 368 non-null    int64
#  13  Diabetes                                                                                  368 non-null    int64
#  14  HTN                                                                                       368 non-null    object
#  15  Allergies                                                                                 368 non-null    object
#  16  BP                                                                                        368 non-null    float64
#  17  Thrombolysis                                                                              368 non-null    int64
#  18  BGR                                                                                       368 non-null    int64
#  19  B.Urea                                                                                    368 non-null    float64
#  20  S.Cr                                                                                      368 non-null    float64
#  21  S.Sodium                                                                                  368 non-null    int64
#  22  S.Potassium                                                                               368 non-null    float64
#  23  S.Chloride                                                                                368 non-null    int64
#  24  C.P.K                                                                                     368 non-null    int64
#  25  CK.MB                                                                                     368 non-null    int64
#  26  ESR                                                                                       368 non-null    int64
#  27  WBC                                                                                       368 non-null    int64
#  28  RBC                                                                                       368 non-null    float64
#  29  Hemoglobin                                                                                368 non-null    float64
#  30  P.C.V                                                                                     368 non-null    float64
#  31  M.C.V                                                                                     368 non-null    float64
#  32  M.C.H                                                                                     368 non-null    float64
#  33  M.C.H.C                                                                                   368 non-null    float64
#  34  PLATELET_COUNT                                                                            368 non-null    int64
#  35  NEUTROPHIL                                                                                368 non-null    float64
#  36  LYMPHO                                                                                    368 non-null    float64
#  37  MONOCYTE                                                                                  368 non-null    float64
#  38  EOSINO                                                                                    368 non-null    int64
#  39  Others                                                                                    368 non-null    object
#  40  CO                                                                                        368 non-null    object
#  41  Diagnosis                                                                                 368 non-null    object
#  42  Hypersensitivity                                                                          368 non-null    object
#  43  cp                                                                                        368 non-null    int64
#  44  trestbps                                                                                  368 non-null    int64
#  45  chol                                                                                      368 non-null    int64
#  46  fbs                                                                                       368 non-null    int64
#  47  restecg                                                                                   368 non-null    int64
#  48  thalach                                                                                   368 non-null    int64
#  49  exang                                                                                     368 non-null    int64
#  50  oldpeak                                                                                   368 non-null    float64
#  51  slope                                                                                     368 non-null    int64
#  52  ca                                                                                        368 non-null    int64
#  53  thal                                                                                      368 non-null    int64
#  54  num                                                                                       368 non-null    int64
#  55  SK                                                                                        368 non-null    int64
#  56  SK.React                                                                                  368 non-null    object
#  57  Reaction                                                                                  368 non-null    int64
#  58  Mortality                                                                                 368 non-null    int64
#  59  Follow.Up                                                                                 368 non-null    int64
# dtypes: float64(14), int64(28), object(18)
# memory usage: 172.6+ KB
# None
#
# Missing values:
#  Age                                                                                         0
# Age.Group                                                                                   0
# Gender                                                                                      0
# Locality                                                                                    0
# Marital status                                                                              0
# Life.Style                                                                                  0
# Sleep                                                                                       0
# Category                                                                                    0
# Depression                                                                                  0
# Hyperlipi                                                                                   0
# Smoking                                                                                     0
# Family.History                                                                              0
# F.History                                                                                   0
# Diabetes                                                                                    0
# HTN                                                                                         0
# Allergies                                                                                   0
# BP                                                                                          0
# Thrombolysis                                                                                0
# BGR                                                                                         0
# B.Urea                                                                                      0
# S.Cr                                                                                        0
# S.Sodium                                                                                    0
# S.Potassium                                                                                 0
# S.Chloride                                                                                  0
# C.P.K                                                                                       0
# CK.MB                                                                                       0
# ESR                                                                                         0
# WBC                                                                                         0
# RBC                                                                                         0
# Hemoglobin                                                                                  0
# P.C.V                                                                                       0
# M.C.V                                                                                       0
# M.C.H                                                                                       0
# M.C.H.C                                                                                     0
# PLATELET_COUNT                                                                              0
# NEUTROPHIL                                                                                  0
# LYMPHO                                                                                      0
# MONOCYTE                                                                                    0
# EOSINO                                                                                      0
# Others                                                                                      0
# CO                                                                                          0
# Diagnosis                                                                                   0
# Hypersensitivity                                                                            0
# cp                                                                                          0
# trestbps                                                                                    0
# chol                                                                                        0
# fbs                                                                                         0
# restecg                                                                                     0
# thalach                                                                                     0
# exang                                                                                       0
# oldpeak                                                                                     0
# slope                                                                                       0
# ca                                                                                          0
# thal                                                                                        0
# num                                                                                         0
# SK                                                                                          0
# SK.React                                                                                    0
# Reaction                                                                                    0
# Mortality                                                                                   0
# Follow.Up                                                                                   0
# dtype: int64
#
# Duplicates: 214
#                                                     count unique  \
# Age                                                 368.0    NaN
# Age.Group                                             368      5
# Gender                                                368      2
# Locality                                              368      2
# Marital status                                        368      2
# Life.Style                                     ...    368      2
# Sleep                                                 368      2
# Category                                              368      2
# Depression                                            368      2
# Hyperlipi                                             368      2
# Smoking                                               368      2
# Family.History                                        368      2
# F.History                                           368.0    NaN
# Diabetes                                            368.0    NaN
# HTN                                                   368      2
# Allergies                                             368      2
# BP                                                  368.0    NaN
# Thrombolysis                                        368.0    NaN
# BGR                                                 368.0    NaN
# B.Urea                                              368.0    NaN
# S.Cr                                                368.0    NaN
# S.Sodium                                            368.0    NaN
# S.Potassium                                         368.0    NaN
# S.Chloride                                          368.0    NaN
# C.P.K                                               368.0    NaN
# CK.MB                                               368.0    NaN
# ESR                                                 368.0    NaN
# WBC                                                 368.0    NaN
# RBC                                                 368.0    NaN
# Hemoglobin                                          368.0    NaN
# P.C.V                                               368.0    NaN
# M.C.V                                               368.0    NaN
# M.C.H                                               368.0    NaN
# M.C.H.C                                             368.0    NaN
# PLATELET_COUNT                                      368.0    NaN
# NEUTROPHIL                                          368.0    NaN
# LYMPHO                                              368.0    NaN
# MONOCYTE                                            368.0    NaN
# EOSINO                                              368.0    NaN
# Others                                                368     17
# CO                                                    368     37
# Diagnosis                                             368     37
# Hypersensitivity                                      368      2
# cp                                                  368.0    NaN
# trestbps                                            368.0    NaN
# chol                                                368.0    NaN
# fbs                                                 368.0    NaN
# restecg                                             368.0    NaN
# thalach                                             368.0    NaN
# exang                                               368.0    NaN
# oldpeak                                             368.0    NaN
# slope                                               368.0    NaN
# ca                                                  368.0    NaN
# thal                                                368.0    NaN
# num                                                 368.0    NaN
# SK                                                  368.0    NaN
# SK.React                                              368      7
# Reaction                                            368.0    NaN
# Mortality                                           368.0    NaN
# Follow.Up                                           368.0    NaN
#
#                                                                top freq  \
# Age                                                            NaN  NaN
# Age.Group                                                    51-60  184
# Gender                                                        Male  285
# Locality                                                     URBAN  234
# Marital status                                             MARRIED  365
# Life.Style                                     ...             YES  217
# Sleep                                                           NO  224
# Category                                                      FREE  331
# Depression                                                     YES  351
# Hyperlipi                                                      YES  341
# Smoking                                                        YES  195
# Family.History                                                  NO  296
# F.History                                                      NaN  NaN
# Diabetes                                                       NaN  NaN
# HTN                                                            YES  201
# Allergies                                                       NO  357
# BP                                                             NaN  NaN
# Thrombolysis                                                   NaN  NaN
# BGR                                                            NaN  NaN
# B.Urea                                                         NaN  NaN
# S.Cr                                                           NaN  NaN
# S.Sodium                                                       NaN  NaN
# S.Potassium                                                    NaN  NaN
# S.Chloride                                                     NaN  NaN
# C.P.K                                                          NaN  NaN
# CK.MB                                                          NaN  NaN
# ESR                                                            NaN  NaN
# WBC                                                            NaN  NaN
# RBC                                                            NaN  NaN
# Hemoglobin                                                     NaN  NaN
# P.C.V                                                          NaN  NaN
# M.C.V                                                          NaN  NaN
# M.C.H                                                          NaN  NaN
# M.C.H.C                                                        NaN  NaN
# PLATELET_COUNT                                                 NaN  NaN
# NEUTROPHIL                                                     NaN  NaN
# LYMPHO                                                         NaN  NaN
# MONOCYTE                                                       NaN  NaN
# EOSINO                                                         NaN  NaN
# Others                                                          no  201
# CO                                                     Chest pain,   84
# Diagnosis                                               AC I/W M.I   44
# Hypersensitivity                                                NO  356
# cp                                                             NaN  NaN
# trestbps                                                       NaN  NaN
# chol                                                           NaN  NaN
# fbs                                                            NaN  NaN
# restecg                                                        NaN  NaN
# thalach                                                        NaN  NaN
# exang                                                          NaN  NaN
# oldpeak                                                        NaN  NaN
# slope                                                          NaN  NaN
# ca                                                             NaN  NaN
# thal                                                           NaN  NaN
# num                                                            NaN  NaN
# SK                                                             NaN  NaN
# SK.React                                            COUGH.BLEEDING  146
# Reaction                                                       NaN  NaN
# Mortality                                                      NaN  NaN
# Follow.Up                                                      NaN  NaN
#
#                                                              mean  \
# Age                                                     54.293478
# Age.Group                                                     NaN
# Gender                                                        NaN
# Locality                                                      NaN
# Marital status                                                NaN
# Life.Style                                     ...            NaN
# Sleep                                                         NaN
# Category                                                      NaN
# Depression                                                    NaN
# Hyperlipi                                                     NaN
# Smoking                                                       NaN
# Family.History                                                NaN
# F.History                                                0.195652
# Diabetes                                                 0.461957
# HTN                                                           NaN
# Allergies                                                     NaN
# BP                                                     121.213315
# Thrombolysis                                             0.032609
# BGR                                                    219.991848
# B.Urea                                                  51.681522
# S.Cr                                                     1.716902
# S.Sodium                                               138.019022
# S.Potassium                                               4.21087
# S.Chloride                                             103.817935
# C.P.K                                                  553.888587
# CK.MB                                                   62.491848
# ESR                                                     26.565217
# WBC                                                  11181.277174
# RBC                                                      5.090217
# Hemoglobin                                               13.90788
# P.C.V                                                    0.415272
# M.C.V                                                   81.574457
# M.C.H                                                   27.265761
# M.C.H.C                                                  0.329429
# PLATELET_COUNT                                      248660.326087
# NEUTROPHIL                                               2.927391
# LYMPHO                                                    0.24894
# MONOCYTE                                                   0.0325
# EOSINO                                                   2.255435
# Others                                                        NaN
# CO                                                            NaN
# Diagnosis                                                     NaN
# Hypersensitivity                                              NaN
# cp                                                       3.671196
# trestbps                                               132.741848
# chol                                                   248.940217
# fbs                                                      0.141304
# restecg                                                   1.07337
# thalach                                                140.923913
# exang                                                      0.5625
# oldpeak                                                  1.541848
# slope                                                    1.842391
# ca                                                       1.002717
# thal                                                     5.858696
# num                                                      2.035326
# SK                                                       0.983696
# SK.React                                                      NaN
# Reaction                                                 0.747283
# Mortality                                                0.217391
# Follow.Up                                               28.652174
#
#                                                              std      min  \
# Age                                                     8.718158     24.0
# Age.Group                                                    NaN      NaN
# Gender                                                       NaN      NaN
# Locality                                                     NaN      NaN
# Marital status                                               NaN      NaN
# Life.Style                                     ...           NaN      NaN
# Sleep                                                        NaN      NaN
# Category                                                     NaN      NaN
# Depression                                                   NaN      NaN
# Hyperlipi                                                    NaN      NaN
# Smoking                                                      NaN      NaN
# Family.History                                               NaN      NaN
# F.History                                               0.397242      0.0
# Diabetes                                                0.499229      0.0
# HTN                                                          NaN      NaN
# Allergies                                                    NaN      NaN
# BP                                                     24.539205     80.5
# Thrombolysis                                            0.177852      0.0
# BGR                                                   139.337387     60.0
# B.Urea                                                 62.582571      2.3
# S.Cr                                                    3.609296      0.6
# S.Sodium                                                4.079879    129.0
# S.Potassium                                             0.394984      3.3
# S.Chloride                                              4.799751     90.0
# C.P.K                                                 957.605017     52.0
# CK.MB                                                  89.789096     14.0
# ESR                                                    32.579496      5.0
# WBC                                                  3517.876535   5800.0
# RBC                                                     0.771962     3.46
# Hemoglobin                                              2.160134      9.1
# P.C.V                                                   0.063948     0.29
# M.C.V                                                   6.812315     60.0
# M.C.H                                                   3.077398     18.0
# M.C.H.C                                                  0.02446     0.22
# PLATELET_COUNT                                      76707.564945  20000.0
# NEUTROPHIL                                             13.401516     0.36
# LYMPHO                                                  0.118959     0.05
# MONOCYTE                                                0.015721     0.01
# EOSINO                                                  0.876563      1.0
# Others                                                       NaN      NaN
# CO                                                           NaN      NaN
# Diagnosis                                                    NaN      NaN
# Hypersensitivity                                             NaN      NaN
# cp                                                      0.772862      1.0
# trestbps                                               18.194265    100.0
# chol                                                   50.126453    131.0
# fbs                                                     0.348809      0.0
# restecg                                                 0.994562      0.0
# thalach                                                22.994601     71.0
# exang                                                   0.496754      0.0
# oldpeak                                                 1.385381      0.0
# slope                                                   0.564284      1.0
# ca                                                      1.037442      0.0
# thal                                                    1.744319      3.0
# num                                                     1.031573      1.0
# SK                                                      0.126816      0.0
# SK.React                                                     NaN      NaN
# Reaction                                                0.435162      0.0
# Mortality                                               0.413033      0.0
# Follow.Up                                               15.81186      1.0
#
#                                                          25%       50%  \
# Age                                                    50.75      55.0
# Age.Group                                                NaN       NaN
# Gender                                                   NaN       NaN
# Locality                                                 NaN       NaN
# Marital status                                           NaN       NaN
# Life.Style                                     ...       NaN       NaN
# Sleep                                                    NaN       NaN
# Category                                                 NaN       NaN
# Depression                                               NaN       NaN
# Hyperlipi                                                NaN       NaN
# Smoking                                                  NaN       NaN
# Family.History                                           NaN       NaN
# F.History                                                0.0       0.0
# Diabetes                                                 0.0       0.0
# HTN                                                      NaN       NaN
# Allergies                                                NaN       NaN
# BP                                                     100.7     120.8
# Thrombolysis                                             0.0       0.0
# BGR                                                    117.0     164.0
# B.Urea                                                  28.0      36.0
# S.Cr                                                     0.9       0.9
# S.Sodium                                               135.0     138.0
# S.Potassium                                              3.9       4.2
# S.Chloride                                             100.0     104.0
# C.P.K                                                  135.0     188.0
# CK.MB                                                   21.0      36.0
# ESR                                                     11.0      16.0
# WBC                                                   7800.0   10650.0
# RBC                                                      4.4       5.2
# Hemoglobin                                              12.3      14.2
# P.C.V                                                   0.36     0.425
# M.C.V                                                   78.0      82.1
# M.C.H                                                   25.7      27.9
# M.C.H.C                                                 0.32      0.33
# PLATELET_COUNT                                      192000.0  237000.0
# NEUTROPHIL                                               0.6      0.72
# LYMPHO                                                  0.17      0.21
# MONOCYTE                                                0.02      0.03
# EOSINO                                                   2.0       2.0
# Others                                                   NaN       NaN
# CO                                                       NaN       NaN
# Diagnosis                                                NaN       NaN
# Hypersensitivity                                         NaN       NaN
# cp                                                       4.0       4.0
# trestbps                                               120.0     130.0
# chol                                                   212.0     249.0
# fbs                                                      0.0       0.0
# restecg                                                  0.0       2.0
# thalach                                                125.0     144.0
# exang                                                    0.0       1.0
# oldpeak                                                0.275       1.2
# slope                                                   1.75       2.0
# ca                                                       0.0       1.0
# thal                                                     3.0       7.0
# num                                                      1.0       2.0
# SK                                                       1.0       1.0
# SK.React                                                 NaN       NaN
# Reaction                                                 0.0       1.0
# Mortality                                                0.0       0.0
# Follow.Up                                               15.0      32.0
#
#                                                          75%       max
# Age                                                    60.25      77.0
# Age.Group                                                NaN       NaN
# Gender                                                   NaN       NaN
# Locality                                                 NaN       NaN
# Marital status                                           NaN       NaN
# Life.Style                                     ...       NaN       NaN
# Sleep                                                    NaN       NaN
# Category                                                 NaN       NaN
# Depression                                               NaN       NaN
# Hyperlipi                                                NaN       NaN
# Smoking                                                  NaN       NaN
# Family.History                                           NaN       NaN
# F.History                                                0.0       1.0
# Diabetes                                                 1.0       1.0
# HTN                                                      NaN       NaN
# Allergies                                                NaN       NaN
# BP                                                     140.7    190.11
# Thrombolysis                                             0.0       1.0
# BGR                                                    291.0     563.0
# B.Urea                                                  43.0     394.0
# S.Cr                                                     1.1      22.9
# S.Sodium                                               141.0     146.0
# S.Potassium                                              4.4       5.3
# S.Chloride                                             107.0     112.0
# C.P.K                                                  390.0    4289.0
# CK.MB                                                   52.0     505.0
# ESR                                                     25.0     154.0
# WBC                                                  13500.0   19590.0
# RBC                                                     5.65      6.98
# Hemoglobin                                              15.5      18.0
# P.C.V                                                   0.46      0.54
# M.C.V                                                   86.0      96.0
# M.C.H                                                   29.0      33.0
# M.C.H.C                                                 0.34      0.39
# PLATELET_COUNT                                      287000.0  459000.0
# NEUTROPHIL                                               0.8      83.0
# LYMPHO                                                  0.32      0.54
# MONOCYTE                                                0.04      0.08
# EOSINO                                                   3.0       5.0
# Others                                                   NaN       NaN
# CO                                                       NaN       NaN
# Diagnosis                                                NaN       NaN
# Hypersensitivity                                         NaN       NaN
# cp                                                       4.0       4.0
# trestbps                                               142.0     200.0
# chol                                                   283.0     409.0
# fbs                                                      0.0       1.0
# restecg                                                  2.0       2.0
# thalach                                                158.0     195.0
# exang                                                    1.0       1.0
# oldpeak                                                  2.2       6.2
# slope                                                    2.0       3.0
# ca                                                       2.0       3.0
# thal                                                     7.0       7.0
# num                                                      3.0       4.0
# SK                                                       1.0       1.0
# SK.React                                                 NaN       NaN
# Reaction                                                 1.0       1.0
# Mortality                                                0.0       1.0
# Follow.Up                                               36.0      60.0

# %%
# Cell 3: Define Features & Target
target = 'Mortality'
X = df.drop(columns=[target])
y = df[target]

num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = X.select_dtypes(include=['object']).columns.tolist()

print("Numeric columns:", num_cols)
print("Categorical columns:", cat_cols)
# Out:
# Numeric columns: ['Age', 'F.History', 'Diabetes', 'BP', 'Thrombolysis', 'BGR', 'B.Urea', 'S.Cr', 'S.Sodium', 'S.Potassium', 'S.Chloride', 'C.P.K', 'CK.MB', 'ESR', 'WBC', 'RBC', 'Hemoglobin', 'P.C.V', 'M.C.V', 'M.C.H', 'M.C.H.C', 'PLATELET_COUNT', 'NEUTROPHIL', 'LYMPHO', 'MONOCYTE', 'EOSINO', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num', 'SK', 'Reaction', 'Follow.Up']
# Categorical columns: ['Age.Group', 'Gender', 'Locality  ', 'Marital status                       ', 'Life.Style                                                                              ', 'Sleep', 'Category', 'Depression', 'Hyperlipi', 'Smoking', 'Family.History', 'HTN', 'Allergies', 'Others ', 'CO', 'Diagnosis', 'Hypersensitivity', 'SK.React']

# %%
# Cell 4: Preprocessing Pipelines
numeric_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('cat', categorical_pipeline, cat_cols)
])

# %%
# Cell 5: Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# Cell 6: Models & Hyperparameter Grids
models = {
    'Decision Tree': (
        DecisionTreeClassifier(random_state=42),
        {
            'clf__max_depth': [None, 5, 10],
            'clf__min_samples_split': [2, 10],
            'clf__min_samples_leaf': [1, 5]
        }
    ),
    'Random Forest': (
        RandomForestClassifier(random_state=42),
        {
            'clf__n_estimators': [100, 200],
            'clf__max_depth': [None, 10],
            'clf__min_samples_leaf': [1, 2]
        }
    ),
    'KNN': (
        KNeighborsClassifier(),
        {
            'clf__n_neighbors': [3, 5, 7],
            'clf__weights': ['uniform', 'distance']
        }
    ),
    'Logistic Regression': (
        LogisticRegression(solver='lbfgs', max_iter=1000),
        {
            'clf__C': [0.01, 0.1, 1, 10],
            'clf__penalty': ['l2']
        }
    )
}

# %%
# Cell 7: GridSearchCV Training & Evaluation
results = []
for name, (model, params) in models.items():
    pipe = Pipeline([('preprocessor', preprocessor), ('clf', model)])
    grid = GridSearchCV(pipe, param_grid=params, cv=5, scoring='roc_auc', n_jobs=-1)
    grid.fit(X_train, y_train)
    best = grid.best_estimator_
    y_pred = best.predict(X_test)
    y_proba = best.predict_proba(X_test)[:, 1] if hasattr(best, "predict_proba") else None

    results.append({
        'Model': name,
        'Best Params': grid.best_params_,
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred),
        'ROC AUC': roc_auc_score(y_test, y_proba) if y_proba is not None else None
    })

# %%
# Cell 8: Show full Best Params without truncation
import pandas as pd
pd.set_option('display.max_colwidth', None)
results_df = pd.DataFrame(results).set_index('Model')
results_df
# Out:
#                                                                                            Best Params  \
# Model
# Decision Tree        {'clf__max_depth': None, 'clf__min_samples_leaf': 5, 'clf__min_samples_split': 2}
# Random Forest           {'clf__max_depth': None, 'clf__min_samples_leaf': 1, 'clf__n_estimators': 200}
# KNN                                                {'clf__n_neighbors': 7, 'clf__weights': 'distance'}
# Logistic Regression                                               {'clf__C': 10, 'clf__penalty': 'l2'}
#
#                      Accuracy  Precision  Recall  F1 Score   ROC AUC
# Model
# Decision Tree        0.959459   0.842105  1.0000  0.914286  0.969289
# Random Forest        0.972973   0.937500  0.9375  0.937500  0.996767
# KNN                  0.945946   0.875000  0.8750  0.875000  0.954741
# Logistic Regression  0.972973   0.937500  0.9375  0.937500  0.929957

# %%
# Cell 9: Random Forest Feature Importances
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# 1) Retrieve the best RF params
rf_params = results_df.loc['Random Forest', 'Best Params']

# 2) Build pipeline with those params
rf_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('clf', RandomForestClassifier(
        n_estimators=rf_params['clf__n_estimators'],
        max_depth=rf_params['clf__max_depth'],
        min_samples_leaf=rf_params.get('clf__min_samples_leaf', 1),
        min_samples_split=rf_params.get('clf__min_samples_split', 2),
        random_state=42
    ))
])

# 3) Fit on training data
rf_pipe.fit(X_train, y_train)

# 4) Extract and display feature importances
importances = rf_pipe.named_steps['clf'].feature_importances_
feat_names = rf_pipe.named_steps['preprocessor'].get_feature_names_out()

imp_df = pd.DataFrame({
    'Feature': feat_names,
    'Importance': importances
}).sort_values('Importance', ascending=False)

print("\nTop 10 Random Forest Features:\n")
print(imp_df.head(10))
# Out:
# Top 10 Random Forest Features:
#
#                  Feature  Importance
# 0               num__Age    0.074577
# 28             num__chol    0.074430
# 44  cat__Age.Group_51-60    0.053072
# 43  cat__Age.Group_41-50    0.047663
# 27         num__trestbps    0.037910
# 31          num__thalach    0.037685
# 35               num__ca    0.034614
# 40        num__Follow.Up    0.033008
# 33          num__oldpeak    0.032655
# 2          num__Diabetes    0.024692
